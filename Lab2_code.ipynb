# %%
import numpy as np

# Define the optimization function
def objective_function(position):
    x, y = position
    return x**2 + y**2

# Initialize PSO parameters
num_particles = 30
num_iterations = 100
dim = 2  # Problem dimensionality
inertia_weight = 0.7
cognitive_coeff = 1.5
social_coeff = 1.5

# Initialize particles: positions and velocities
positions = np.random.uniform(-10, 10, (num_particles, dim))
velocities = np.random.uniform(-1, 1, (num_particles, dim))
personal_best_positions = positions.copy()
personal_best_scores = np.array([objective_function(pos) for pos in positions])
global_best_position = personal_best_positions[np.argmin(personal_best_scores)]

# Main PSO loop
for iteration in range(num_iterations):
    for i in range(num_particles):
        # Update particle velocity
        r1, r2 = np.random.rand(), np.random.rand()
        cognitive = cognitive_coeff * r1 * (personal_best_positions[i] - positions[i])
        social = social_coeff * r2 * (global_best_position - positions[i])
        velocities[i] = inertia_weight * velocities[i] + cognitive + social

        # Update particle position
        positions[i] += velocities[i]

        # Evaluate fitness and update personal bests
        fitness = objective_function(positions[i])
        if fitness < personal_best_scores[i]:
            personal_best_scores[i] = fitness
            personal_best_positions[i] = positions[i]

    # Update global best
    best_particle_index = np.argmin(personal_best_scores)
    global_best_position = personal_best_positions[best_particle_index]

    print(f"Iteration {iteration + 1}, Best Fitness: {personal_best_scores[best_particle_index]}")

# Output the best solution
print(f"\nOptimal Solution: {global_best_position}, Optimal Value: {personal_best_scores[best_particle_index]}")
# Out:
# Iteration 1, Best Fitness: 0.6367902594478319
# Iteration 2, Best Fitness: 0.46243856879285267
# Iteration 3, Best Fitness: 0.09830153216760776
# Iteration 4, Best Fitness: 0.09830153216760776
# Iteration 5, Best Fitness: 0.022273509556978106
# Iteration 6, Best Fitness: 0.022273509556978106
# Iteration 7, Best Fitness: 0.022273509556978106
# Iteration 8, Best Fitness: 0.022273509556978106
# Iteration 9, Best Fitness: 0.018515627166888617
# Iteration 10, Best Fitness: 0.018515627166888617
# Iteration 11, Best Fitness: 0.00876056429989096
# Iteration 12, Best Fitness: 0.00876056429989096
# Iteration 13, Best Fitness: 0.00876056429989096
# Iteration 14, Best Fitness: 0.00303885056253007
# Iteration 15, Best Fitness: 0.00303885056253007
# Iteration 16, Best Fitness: 0.00303885056253007
# Iteration 17, Best Fitness: 0.0016314274208799888
# Iteration 18, Best Fitness: 0.0016314274208799888
# Iteration 19, Best Fitness: 0.0008209829135311212
# Iteration 20, Best Fitness: 0.0007722880131834662
# Iteration 21, Best Fitness: 0.0007722880131834662
# Iteration 22, Best Fitness: 0.0004891321021662632
# Iteration 23, Best Fitness: 0.00037814438655963013
# Iteration 24, Best Fitness: 0.00024360854556772452
# Iteration 25, Best Fitness: 4.8962687837842087e-05
# Iteration 26, Best Fitness: 1.900558585644523e-05
# Iteration 27, Best Fitness: 1.900558585644523e-05
# Iteration 28, Best Fitness: 1.6214376819020026e-05
# Iteration 29, Best Fitness: 1.6214376819020026e-05
# Iteration 30, Best Fitness: 1.6214376819020026e-05
# Iteration 31, Best Fitness: 2.1249615655274146e-06
# Iteration 32, Best Fitness: 2.1249615655274146e-06
# Iteration 33, Best Fitness: 2.1249615655274146e-06
# Iteration 34, Best Fitness: 2.1249615655274146e-06
# Iteration 35, Best Fitness: 2.1249615655274146e-06
# Iteration 36, Best Fitness: 2.1249615655274146e-06
# Iteration 37, Best Fitness: 2.1249615655274146e-06
# Iteration 38, Best Fitness: 2.1249615655274146e-06
# Iteration 39, Best Fitness: 2.1249615655274146e-06
# Iteration 40, Best Fitness: 2.1249615655274146e-06
# Iteration 41, Best Fitness: 2.1249615655274146e-06
# Iteration 42, Best Fitness: 7.435893797378179e-07
# Iteration 43, Best Fitness: 3.696731515259325e-07
# Iteration 44, Best Fitness: 3.696731515259325e-07
# Iteration 45, Best Fitness: 8.14045186184291e-08
# Iteration 46, Best Fitness: 8.14045186184291e-08
# Iteration 47, Best Fitness: 6.679998288786125e-08
# Iteration 48, Best Fitness: 6.679998288786125e-08
# Iteration 49, Best Fitness: 6.679998288786125e-08
# Iteration 50, Best Fitness: 6.679998288786125e-08
# Iteration 51, Best Fitness: 4.501462545994892e-08
# Iteration 52, Best Fitness: 4.501462545994892e-08
# Iteration 53, Best Fitness: 4.501462545994892e-08
# Iteration 54, Best Fitness: 4.501462545994892e-08
# Iteration 55, Best Fitness: 4.501462545994892e-08
# Iteration 56, Best Fitness: 4.501462545994892e-08
# Iteration 57, Best Fitness: 4.501462545994892e-08
# Iteration 58, Best Fitness: 2.23613315785277e-08
# Iteration 59, Best Fitness: 2.1258448006511825e-08
# Iteration 60, Best Fitness: 9.72470849348817e-09
# Iteration 61, Best Fitness: 9.72470849348817e-09
# Iteration 62, Best Fitness: 9.345079933987554e-09
# Iteration 63, Best Fitness: 9.345079933987554e-09
# Iteration 64, Best Fitness: 9.345079933987554e-09
# Iteration 65, Best Fitness: 9.345079933987554e-09
# Iteration 66, Best Fitness: 2.7906582132726942e-09
# Iteration 67, Best Fitness: 2.7906582132726942e-09
# Iteration 68, Best Fitness: 1.8497004933331642e-09
# Iteration 69, Best Fitness: 2.0529962556160204e-10
# Iteration 70, Best Fitness: 2.0529962556160204e-10
# Iteration 71, Best Fitness: 2.0529962556160204e-10
# Iteration 72, Best Fitness: 2.0529962556160204e-10
# Iteration 73, Best Fitness: 1.3007112259747753e-10
# Iteration 74, Best Fitness: 1.3007112259747753e-10
# Iteration 75, Best Fitness: 1.3007112259747753e-10
# Iteration 76, Best Fitness: 5.121024770752816e-11
# Iteration 77, Best Fitness: 5.121024770752816e-11
# Iteration 78, Best Fitness: 5.121024770752816e-11
# Iteration 79, Best Fitness: 1.184706346912974e-11
# Iteration 80, Best Fitness: 1.184706346912974e-11
# Iteration 81, Best Fitness: 1.184706346912974e-11
# Iteration 82, Best Fitness: 7.87961070011448e-12
# Iteration 83, Best Fitness: 1.5761865799386603e-12
# Iteration 84, Best Fitness: 1.5761865799386603e-12
# Iteration 85, Best Fitness: 2.2032965226899401e-13
# Iteration 86, Best Fitness: 2.2032965226899401e-13
# Iteration 87, Best Fitness: 2.2032965226899401e-13
# Iteration 88, Best Fitness: 2.2032965226899401e-13
# Iteration 89, Best Fitness: 2.2032965226899401e-13
# Iteration 90, Best Fitness: 2.2032965226899401e-13
# Iteration 91, Best Fitness: 2.2032965226899401e-13
# Iteration 92, Best Fitness: 2.2032965226899401e-13
# Iteration 93, Best Fitness: 1.7225512222562156e-13
# Iteration 94, Best Fitness: 1.7225512222562156e-13
# Iteration 95, Best Fitness: 1.7225512222562156e-13
# Iteration 96, Best Fitness: 1.7225512222562156e-13
# Iteration 97, Best Fitness: 1.7225512222562156e-13
# Iteration 98, Best Fitness: 1.7225512222562156e-13
# Iteration 99, Best Fitness: 1.7110532524438862e-13
# Iteration 100, Best Fitness: 1.7110532524438862e-13
#
# Optimal Solution: [ 4.13137883e-07 -2.05527371e-08], Optimal Value: 1.7110532524438862e-13
